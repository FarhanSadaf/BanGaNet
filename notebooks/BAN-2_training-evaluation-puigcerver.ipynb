# %%
# !nvidia-smi
# Out:
# Sun May  1 12:21:18 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip uninstall opencv-python-headless==4.5.5.62
# !pip install opencv-python-headless==4.5.2.52

# !pip install -U albumentations

# %%
# %tensorflow_version 2.x
import tensorflow as tf

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/My Drive/'

import os

BASE_DIR = os.getcwd()

# BASE_DIR is working directory for this notebook
print(BASE_DIR)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive
# /content/drive/My Drive

# %% [markdown]
# ## Import libraries

# %%
import string
import json
import numpy as np
import matplotlib.pyplot as plt

from htr.preprocessing import get_augmentation_pipeline
from htr.generator import DataGenerator
from htr.network.models import *

from htr.evaluation import ocr_metrics

from tensorflow.keras.models import Model

# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# ***Filepaths***

# %%
# dataset_path = os.path.join(BASE_DIR, 'htr', 'data', 'BanglaWriting1.hdf5')
dataset_path = os.path.join(BASE_DIR, 'htr', 'data', 'BanglaWriting_128_64.hdf5')

# %% [markdown]
# ***Parameters***

# %%
# input_size = (256, 64, 1)
# max_text_len = 32
input_size = (128, 64, 1)
max_text_len = 16
batch_size = 32
epochs = 200

# charset = ''.join(json.load(open(os.path.join(BASE_DIR, 'htr', 'data', 'BanglaWriting-characters.json'))))

charlist = json.load(open(os.path.join(BASE_DIR, 'htr', 'data', 'BanglaWriting-characters.json')))
charlist.remove(' ')
charset = ''.join(charlist)
print(len(charset))
# Out:
# 90

# %% [markdown]
# ***DataGenerator class***

# %%
generator = DataGenerator(dataset_path=dataset_path, 
                          input_size=input_size, 
                          batch_size=batch_size, 
                          max_text_len=max_text_len, 
                          charset=charset,
                          aug=get_augmentation_pipeline(),
                          encoding='utf-8')

print('Images:', generator._size)
# Out:
# /usr/local/lib/python3.7/dist-packages/albumentations/augmentations/transforms.py:691: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,
# Images: {'train': 18663, 'val': 829, 'test': 1244}

# %% [markdown]
# ## *Puigcerver*
# ### Model

# %%
output_path = os.path.join(BASE_DIR, 'htr', 'data2', 'output-bangla-puigcerver-ts16')
target_path = os.path.join(output_path, 'checkpoint_weights.hdf5')

# %%
inputs, outputs = puigcerver(input_size=input_size, d_model=generator.tokenizer.vocab_size + 1)

model = Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 128, 64, 1)]      0
#
#  conv2d_5 (Conv2D)           (None, 128, 64, 16)       160
#
#  batch_normalization_5 (Batc  (None, 128, 64, 16)      64
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 128, 64, 16)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 64, 32, 16)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 64, 32, 32)        4640
#
#  batch_normalization_6 (Batc  (None, 64, 32, 32)       128
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 64, 32, 32)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 32, 16, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 32, 16, 32)        0
#
#  conv2d_7 (Conv2D)           (None, 32, 16, 48)        13872
#
#  batch_normalization_7 (Batc  (None, 32, 16, 48)       192
#  hNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32, 16, 48)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 8, 48)        0
#  2D)
#
#  dropout_5 (Dropout)         (None, 16, 8, 48)         0
#
#  conv2d_8 (Conv2D)           (None, 16, 8, 64)         27712
#
#  batch_normalization_8 (Batc  (None, 16, 8, 64)        256
#  hNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 16, 8, 64)         0
#
#  dropout_6 (Dropout)         (None, 16, 8, 64)         0
#
#  conv2d_9 (Conv2D)           (None, 16, 8, 80)         46160
#
#  batch_normalization_9 (Batc  (None, 16, 8, 80)        320
#  hNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 16, 8, 80)         0
#
#  reshape_1 (Reshape)         (None, 16, 640)           0
#
#  bidirectional_5 (Bidirectio  (None, 16, 512)          1837056
#  nal)
#
#  bidirectional_6 (Bidirectio  (None, 16, 512)          1574912
#  nal)
#
#  bidirectional_7 (Bidirectio  (None, 16, 512)          1574912
#  nal)
#
#  bidirectional_8 (Bidirectio  (None, 16, 512)          1574912
#  nal)
#
#  bidirectional_9 (Bidirectio  (None, 16, 512)          1574912
#  nal)
#
#  dropout_7 (Dropout)         (None, 16, 512)           0
#
#  dense_1 (Dense)             (None, 16, 93)            47709
#
# =================================================================
# Total params: 8,277,917
# Trainable params: 8,277,437
# Non-trainable params: 480
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=ctc_loss)

# Load weights from target_path
if os.path.isfile(target_path):
    model.load_weights(target_path)
    print('===== Pre-trained weights loaded =====')
# Out:
# ===== Pre-trained weights loaded =====

# %% [markdown]
# ### Training

# %%
callbacks = get_callbacks(logdir=output_path, 
                          checkpoint_filepath=target_path, 
                          verbose=1, 
                          stop_patience=15, 
                          reduce_patience=4)

# %%
model.fit(x=generator.next_train_batch(), 
          steps_per_epoch=generator._steps['train'], 
          validation_data=generator.next_val_batch(), 
          validation_steps=generator._steps['val'], 
          epochs=epochs, 
          callbacks=callbacks, 
          verbose=1)
# Out:
# Epoch 1/200
# 584/584 [==============================] - ETA: 0s - loss: 2.8451
# Epoch 1: val_loss improved from inf to 3.07211, saving model to /content/drive/My Drive/htr/data2/output-bangla-puigcerver-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 116s 162ms/step - loss: 2.8451 - val_loss: 3.0721 - lr: 0.0010
# Epoch 2/200
# 584/584 [==============================] - ETA: 0s - loss: 2.8918
# Epoch 2: val_loss did not improve from 3.07211
# 584/584 [==============================] - 92s 158ms/step - loss: 2.8918 - val_loss: 3.2073 - lr: 0.0010
# Epoch 3/200
# 584/584 [==============================] - ETA: 0s - loss: 2.9199
# Epoch 3: val_loss improved from 3.07211 to 2.92282, saving model to /content/drive/My Drive/htr/data2/output-bangla-puigcerver-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 92s 158ms/step - loss: 2.9199 - val_loss: 2.9228 - lr: 0.0010
# Epoch 4/200
# 584/584 [==============================] - ETA: 0s - loss: 2.9079
# Epoch 4: val_loss did not improve from 2.92282
# 584/584 [==============================] - 93s 159ms/step - loss: 2.9079 - val_loss: 4.6036 - lr: 0.0010
# Epoch 5/200
# 584/584 [==============================] - ETA: 0s - loss: 2.8994
# Epoch 5: val_loss did not improve from 2.92282
# 584/584 [==============================] - 94s 161ms/step - loss: 2.8994 - val_loss: 2.9366 - lr: 0.0010
# Epoch 6/200
# 584/584 [==============================] - ETA: 0s - loss: 2.8512
# Epoch 6: val_loss did not improve from 2.92282
# 584/584 [==============================] - 88s 151ms/step - loss: 2.8512 - val_loss: 15.1860 - lr: 0.0010
# Epoch 7/200
# 584/584 [==============================] - ETA: 0s - loss: 2.7955
# Epoch 7: val_loss did not improve from 2.92282
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 584/584 [==============================] - 88s 150ms/step - loss: 2.7955 - val_loss: 10.3395 - lr: 0.0010
# Epoch 8/200
# 584/584 [==============================] - ETA: 0s - loss: 2.5449
# Epoch 8: val_loss improved from 2.92282 to 2.68409, saving model to /content/drive/My Drive/htr/data2/output-bangla-puigcerver-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 89s 152ms/step - loss: 2.5449 - val_loss: 2.6841 - lr: 2.0000e-04
# Epoch 9/200
# 584/584 [==============================] - ETA: 0s - loss: 2.3833
# Epoch 9: val_loss improved from 2.68409 to 2.60193, saving model to /content/drive/My Drive/htr/data2/output-bangla-puigcerver-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 95s 163ms/step - loss: 2.3833 - val_loss: 2.6019 - lr: 2.0000e-04
# Epoch 10/200
# 584/584 [==============================] - ETA: 0s - loss: 2.3235
# Epoch 10: val_loss did not improve from 2.60193
# 584/584 [==============================] - 95s 163ms/step - loss: 2.3235 - val_loss: 2.6831 - lr: 2.0000e-04
# Epoch 11/200
# 584/584 [==============================] - ETA: 0s - loss: 2.2462
# Epoch 11: val_loss did not improve from 2.60193
# 584/584 [==============================] - 95s 163ms/step - loss: 2.2462 - val_loss: 2.6970 - lr: 2.0000e-04
# Epoch 12/200
# 584/584 [==============================] - ETA: 0s - loss: 2.2115
# Epoch 12: val_loss did not improve from 2.60193
# 584/584 [==============================] - 94s 162ms/step - loss: 2.2115 - val_loss: 2.6385 - lr: 2.0000e-04
# Epoch 13/200
# 584/584 [==============================] - ETA: 0s - loss: 2.1757
# Epoch 13: val_loss did not improve from 2.60193
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 584/584 [==============================] - 94s 161ms/step - loss: 2.1757 - val_loss: 2.6896 - lr: 2.0000e-04
# Epoch 14/200
# 584/584 [==============================] - ETA: 0s - loss: 2.1103
# Epoch 14: val_loss did not improve from 2.60193
# 584/584 [==============================] - 93s 159ms/step - loss: 2.1103 - val_loss: 2.6275 - lr: 4.0000e-05
# Epoch 15/200
# 584/584 [==============================] - ETA: 0s - loss: 2.0731
# Epoch 15: val_loss did not improve from 2.60193
# 584/584 [==============================] - 90s 155ms/step - loss: 2.0731 - val_loss: 2.6522 - lr: 4.0000e-05
# Epoch 16/200
# 584/584 [==============================] - ETA: 0s - loss: 2.0367
# Epoch 16: val_loss did not improve from 2.60193
# 584/584 [==============================] - 95s 162ms/step - loss: 2.0367 - val_loss: 2.6394 - lr: 4.0000e-05
# Epoch 17/200
# 584/584 [==============================] - ETA: 0s - loss: 2.0702
# Epoch 17: val_loss did not improve from 2.60193
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 584/584 [==============================] - 95s 162ms/step - loss: 2.0702 - val_loss: 2.6734 - lr: 4.0000e-05
# Epoch 18/200
# 584/584 [==============================] - ETA: 0s - loss: 2.0730
# Epoch 18: val_loss did not improve from 2.60193
# 584/584 [==============================] - 94s 160ms/step - loss: 2.0730 - val_loss: 2.6674 - lr: 8.0000e-06
# Epoch 19/200
# 584/584 [==============================] - ETA: 0s - loss: 2.0767
# Epoch 19: val_loss did not improve from 2.60193
# 584/584 [==============================] - 96s 164ms/step - loss: 2.0767 - val_loss: 2.6633 - lr: 8.0000e-06
# Epoch 20/200
# 584/584 [==============================] - ETA: 0s - loss: 2.0522
# Epoch 20: val_loss did not improve from 2.60193
# 584/584 [==============================] - 94s 161ms/step - loss: 2.0522 - val_loss: 2.6515 - lr: 8.0000e-06
# Epoch 21/200
# 584/584 [==============================] - ETA: 0s - loss: 2.0635
# Epoch 21: val_loss did not improve from 2.60193
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 584/584 [==============================] - 91s 156ms/step - loss: 2.0635 - val_loss: 2.6612 - lr: 8.0000e-06
# Epoch 22/200
# 584/584 [==============================] - ETA: 0s - loss: 2.0499
# Epoch 22: val_loss did not improve from 2.60193
# 584/584 [==============================] - 95s 162ms/step - loss: 2.0499 - val_loss: 2.6557 - lr: 1.6000e-06
# Epoch 23/200
# 584/584 [==============================] - ETA: 0s - loss: 2.0347
# Epoch 23: val_loss did not improve from 2.60193
# 584/584 [==============================] - 93s 159ms/step - loss: 2.0347 - val_loss: 2.6588 - lr: 1.6000e-06
# Epoch 24/200
# 584/584 [==============================] - ETA: 0s - loss: 2.0261
# Epoch 24: val_loss did not improve from 2.60193
# Restoring model weights from the end of the best epoch: 9.
# 584/584 [==============================] - 95s 163ms/step - loss: 2.0261 - val_loss: 2.6559 - lr: 1.6000e-06
# Epoch 24: early stopping

# %% [markdown]
# *Training history from CSVLogger callback*

# %%
from pandas import read_csv
from scipy.signal import savgol_filter
from ipywidgets import interact

path = os.path.join(output_path, 'epochs.log')
if os.path.isfile(path):
    history = read_csv(path)
    loss = history['loss']
    val_loss = history['val_loss']

    print('Min val_loss:', np.min(val_loss))
    print('Min val_loss epoch:', np.argmin(val_loss))

    # Plot training vs validation loss
    plt.figure(figsize=(10, 6))
    plt.plot(loss, 'r.')
    plt.plot(val_loss, 'b.')
    # Smoothing
    plt.plot(savgol_filter(loss, 11, 3), 'r-', label='Training')
    plt.plot(savgol_filter(val_loss, 11, 3), 'b-', label='Validation')
    plt.title('Training and validation loss')
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend()
    plt.grid('on')
    plt.show()
    
else:
    print("File doesn't exist")
# Out:
# Min val_loss: 2.6019301414489746
# Min val_loss epoch: 67

# %% [markdown]
# *Logs from Tensorboard*
#
# If tensorboard gets timed out or doesn't show up, it might be running on http://localhost:6006/.

# %%
# !find /content/drive/My\Drive/htr/data/output-bangla-puigcerver | grep tfevents
# Out:
# /content/drive/MyDrive/htr/data/output-bangla-puigcerver/train/events.out.tfevents.1626284361.cababbe7370e.2024.5279.v2
# /content/drive/MyDrive/htr/data/output-bangla-puigcerver/train/events.out.tfevents.1626359418.c0281027cffe.62.5341.v2
# /content/drive/MyDrive/htr/data/output-bangla-puigcerver/validation/events.out.tfevents.1626359619.c0281027cffe.62.28833.v2

# %%
# %tensorboard --logdir /content/drive/My\Drive/htr/data/output-bangla-puigcerver

# %% [markdown]
# ### Prediction | Evaluation

# %% [markdown]
# ***Validation set***

# %%
print('           VALIDATION SET           ')
Y_pred = model.predict(x=generator.next_val_batch(), steps=generator._steps['val'], verbose=1)
print('Y_pred shape:', Y_pred.shape)

# Predictions, Probabilities after decoding
predictions, probabilities = ctc_decode(Y_pred=Y_pred, batch_size=batch_size, verbose=1)
print('\nCTC decoded predictions len:', len(predictions))

pred_texts = [generator.tokenizer.decode(y) for y in predictions]
gt_texts = [y.decode() for y in generator.dataset['val']['gt_texts']]

cer, wer, ser = ocr_metrics(pred_texts, gt_texts, lower=False) * 100
print(f'Character Error Rate (%) : {cer:.4f}')
print(f'Word Error Rate (%) : {wer:.4f}')
print(f'Sequence Error Rate (%) : {ser:.4f}')
# Out:
#            VALIDATION SET
# 26/26 [==============================] - 5s 58ms/step
# Y_pred shape: (829, 16, 93)
# 26/26 [==============================] - 10s 384ms/step
#
# CTC decoded predictions len: 829
# Character Error Rate (%) : 15.8945
# Word Error Rate (%) : 38.9626
# Sequence Error Rate (%) : 38.9626

# %% [markdown]
# ***Test set***

# %%
print('           TEST SET           ')
Y_pred = model.predict(x=generator.next_test_batch(), steps=generator._steps['test'], verbose=1)
print('Y_pred shape:', Y_pred.shape)

# Predictions, Probabilities after decoding
predictions, probabilities = ctc_decode(Y_pred=Y_pred, batch_size=batch_size, verbose=1)
print('\nCTC decoded predictions len:', len(predictions))

pred_texts = [generator.tokenizer.decode(y) for y in predictions]
gt_texts = [y.decode() for y in generator.dataset['test']['gt_texts']]

cer, wer, ser = ocr_metrics(pred_texts, gt_texts, lower=False) * 100
print(f'Character Error Rate (%) : {cer:.4f}')
print(f'Word Error Rate (%) : {wer:.4f}')
print(f'Sequence Error Rate (%) : {ser:.4f}')
# Out:
#            TEST SET
# 39/39 [==============================] - 7s 56ms/step
# Y_pred shape: (1244, 16, 93)
# 39/39 [==============================] - 17s 427ms/step
#
# CTC decoded predictions len: 1244
# Character Error Rate (%) : 16.2188
# Word Error Rate (%) : 37.1785
# Sequence Error Rate (%) : 37.2186
