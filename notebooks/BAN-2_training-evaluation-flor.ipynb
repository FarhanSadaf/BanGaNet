# %%
# !nvidia-smi
# Out:
# Sun May  1 12:20:37 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8    31W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %tensorflow_version 2.x
import tensorflow as tf

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/My Drive/'

import os

BASE_DIR = os.getcwd()

# BASE_DIR is working directory for this notebook
print(BASE_DIR)
# Out:
# Mounted at /content/drive
# /content/drive/My Drive
# /content/drive/My Drive

# %% [markdown]
# ## Import libraries

# %%
# !pip uninstall opencv-python-headless==4.5.5.62
# !pip install opencv-python-headless==4.5.2.52

# !pip install -U albumentations

# %%
import string
import json
import numpy as np
import matplotlib.pyplot as plt

from htr.preprocessing import get_augmentation_pipeline
from htr.generator import DataGenerator
from htr.network.models import *

from htr.evaluation import ocr_metrics

from tensorflow.keras.models import Model

# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %% [markdown]
# ***Filepaths***

# %%
# dataset_path = os.path.join(BASE_DIR, 'htr', 'data', 'BanglaWriting1.hdf5')
dataset_path = os.path.join(BASE_DIR, 'htr', 'data', 'BanglaWriting_128_64.hdf5')

# %% [markdown]
# ***Parameters***

# %%
# input_size = (256, 64, 1)
# max_text_len = 32
input_size = (128, 64, 1)
max_text_len = 16
batch_size = 32
epochs = 200

# charset = ''.join(json.load(open(os.path.join(BASE_DIR, 'htr', 'data', 'BanglaWriting-characters.json'))))

charlist = json.load(open(os.path.join(BASE_DIR, 'htr', 'data', 'BanglaWriting-characters.json')))
charlist.remove(' ')
charset = ''.join(charlist)
print(len(charset))
# Out:
# 90

# %% [markdown]
# ***DataGenerator class***

# %%
generator = DataGenerator(dataset_path=dataset_path,
                          input_size=input_size,
                          batch_size=batch_size,
                          max_text_len=max_text_len,
                          charset=charset,
                          aug= get_augmentation_pipeline(),
                          encoding='utf-8')

print('Images:', generator._size)
# Out:
# /usr/local/lib/python3.7/dist-packages/albumentations/augmentations/transforms.py:691: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,
# Images: {'train': 18663, 'val': 829, 'test': 1244}

# %% [markdown]
# ## *Flor*
# ### Model

# %%
output_path = os.path.join(BASE_DIR, 'htr', 'data2', 'output-bangla-flor-ts16')
target_path = os.path.join(output_path, 'checkpoint_weights.hdf5')

# %%
inputs, outputs = flor(input_size=input_size, d_model=generator.tokenizer.vocab_size + 1)

model = Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 128, 64, 1)]      0
#
#  conv2d (Conv2D)             (None, 64, 32, 16)        160
#
#  p_re_lu (PReLU)             (None, 64, 32, 16)        16
#
#  batch_normalization (BatchN  (None, 64, 32, 16)       112
#  ormalization)
#
#  full_gated_conv2d (FullGate  (None, 64, 32, 16)       4640
#  dConv2D)
#
#  conv2d_1 (Conv2D)           (None, 64, 32, 32)        4640
#
#  p_re_lu_1 (PReLU)           (None, 64, 32, 32)        32
#
#  batch_normalization_1 (Batc  (None, 64, 32, 32)       224
#  hNormalization)
#
#  full_gated_conv2d_1 (FullGa  (None, 64, 32, 32)       18496
#  tedConv2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 8, 40)         10280
#
#  p_re_lu_2 (PReLU)           (None, 32, 8, 40)         40
#
#  batch_normalization_2 (Batc  (None, 32, 8, 40)        280
#  hNormalization)
#
#  full_gated_conv2d_2 (FullGa  (None, 32, 8, 40)        28880
#  tedConv2D)
#
#  dropout (Dropout)           (None, 32, 8, 40)         0
#
#  conv2d_3 (Conv2D)           (None, 32, 8, 48)         17328
#
#  p_re_lu_3 (PReLU)           (None, 32, 8, 48)         48
#
#  batch_normalization_3 (Batc  (None, 32, 8, 48)        336
#  hNormalization)
#
#  full_gated_conv2d_3 (FullGa  (None, 32, 8, 48)        41568
#  tedConv2D)
#
#  dropout_1 (Dropout)         (None, 32, 8, 48)         0
#
#  conv2d_4 (Conv2D)           (None, 16, 2, 56)         21560
#
#  p_re_lu_4 (PReLU)           (None, 16, 2, 56)         56
#
#  batch_normalization_4 (Batc  (None, 16, 2, 56)        392
#  hNormalization)
#
#  full_gated_conv2d_4 (FullGa  (None, 16, 2, 56)        56560
#  tedConv2D)
#
#  dropout_2 (Dropout)         (None, 16, 2, 56)         0
#
#  conv2d_5 (Conv2D)           (None, 16, 2, 64)         32320
#
#  p_re_lu_5 (PReLU)           (None, 16, 2, 64)         64
#
#  batch_normalization_5 (Batc  (None, 16, 2, 64)        448
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 1, 64)        0
#  )
#
#  reshape (Reshape)           (None, 16, 64)            0
#
#  bidirectional (Bidirectiona  (None, 16, 256)          148992
#  l)
#
#  dense (Dense)               (None, 16, 256)           65792
#
#  bidirectional_1 (Bidirectio  (None, 16, 256)          296448
#  nal)
#
#  dense_1 (Dense)             (None, 16, 93)            23901
#
# =================================================================
# Total params: 773,613
# Trainable params: 772,333
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=ctc_loss)

# Load weights from target_path
if os.path.isfile(target_path):
    model.load_weights(target_path)
    print('===== Pre-trained weights loaded =====')
# Out:
# ===== Pre-trained weights loaded =====

# %% [markdown]
# ### Training

# %%
callbacks = get_callbacks(logdir=output_path,
                          checkpoint_filepath=target_path,
                          verbose=1,
                          stop_patience=20,
                          reduce_patience=4)

# %%
model.fit(x=generator.next_train_batch(),
          steps_per_epoch=generator._steps['train'],
          validation_data=generator.next_val_batch(),
          validation_steps=generator._steps['val'],
          epochs=epochs,
          callbacks=callbacks,
          verbose=1)
# Out:
# Epoch 1/200
# 584/584 [==============================] - ETA: 0s - loss: 2.1617
# Epoch 1: val_loss improved from inf to 2.65535, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 96s 139ms/step - loss: 2.1617 - val_loss: 2.6553 - lr: 0.0010
# Epoch 2/200
# 584/584 [==============================] - ETA: 0s - loss: 2.3402
# Epoch 2: val_loss improved from 2.65535 to 2.55926, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 83s 141ms/step - loss: 2.3402 - val_loss: 2.5593 - lr: 0.0010
# Epoch 3/200
# 584/584 [==============================] - ETA: 0s - loss: 2.3391
# Epoch 3: val_loss did not improve from 2.55926
# 584/584 [==============================] - 84s 144ms/step - loss: 2.3391 - val_loss: 2.6540 - lr: 0.0010
# Epoch 4/200
# 584/584 [==============================] - ETA: 0s - loss: 2.3369
# Epoch 4: val_loss did not improve from 2.55926
# 584/584 [==============================] - 85s 145ms/step - loss: 2.3369 - val_loss: 2.5981 - lr: 0.0010
# Epoch 5/200
# 584/584 [==============================] - ETA: 0s - loss: 2.3272
# Epoch 5: val_loss did not improve from 2.55926
# 584/584 [==============================] - 83s 142ms/step - loss: 2.3272 - val_loss: 2.7970 - lr: 0.0010
# Epoch 6/200
# 584/584 [==============================] - ETA: 0s - loss: 2.3116
# Epoch 6: val_loss did not improve from 2.55926
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 584/584 [==============================] - 83s 142ms/step - loss: 2.3116 - val_loss: 2.6065 - lr: 0.0010
# Epoch 7/200
# 584/584 [==============================] - ETA: 0s - loss: 1.9678
# Epoch 7: val_loss improved from 2.55926 to 2.51453, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 85s 146ms/step - loss: 1.9678 - val_loss: 2.5145 - lr: 2.0000e-04
# Epoch 8/200
# 584/584 [==============================] - ETA: 0s - loss: 1.8685
# Epoch 8: val_loss improved from 2.51453 to 2.44815, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 83s 143ms/step - loss: 1.8685 - val_loss: 2.4482 - lr: 2.0000e-04
# Epoch 9/200
# 584/584 [==============================] - ETA: 0s - loss: 1.7937
# Epoch 9: val_loss improved from 2.44815 to 2.39818, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 85s 146ms/step - loss: 1.7937 - val_loss: 2.3982 - lr: 2.0000e-04
# Epoch 10/200
# 584/584 [==============================] - ETA: 0s - loss: 1.7463
# Epoch 10: val_loss improved from 2.39818 to 2.34548, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 84s 144ms/step - loss: 1.7463 - val_loss: 2.3455 - lr: 2.0000e-04
# Epoch 11/200
# 584/584 [==============================] - ETA: 0s - loss: 1.7237
# Epoch 11: val_loss did not improve from 2.34548
# 584/584 [==============================] - 83s 142ms/step - loss: 1.7237 - val_loss: 2.3699 - lr: 2.0000e-04
# Epoch 12/200
# 584/584 [==============================] - ETA: 0s - loss: 1.6754
# Epoch 12: val_loss did not improve from 2.34548
# 584/584 [==============================] - 83s 142ms/step - loss: 1.6754 - val_loss: 2.3676 - lr: 2.0000e-04
# Epoch 13/200
# 584/584 [==============================] - ETA: 0s - loss: 1.6338
# Epoch 13: val_loss improved from 2.34548 to 2.31730, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 84s 144ms/step - loss: 1.6338 - val_loss: 2.3173 - lr: 2.0000e-04
# Epoch 14/200
# 584/584 [==============================] - ETA: 0s - loss: 1.6504
# Epoch 14: val_loss did not improve from 2.31730
# 584/584 [==============================] - 83s 142ms/step - loss: 1.6504 - val_loss: 2.3402 - lr: 2.0000e-04
# Epoch 15/200
# 584/584 [==============================] - ETA: 0s - loss: 1.6190
# Epoch 15: val_loss did not improve from 2.31730
# 584/584 [==============================] - 82s 141ms/step - loss: 1.6190 - val_loss: 2.3255 - lr: 2.0000e-04
# Epoch 16/200
# 584/584 [==============================] - ETA: 0s - loss: 1.6071
# Epoch 16: val_loss improved from 2.31730 to 2.29702, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 86s 146ms/step - loss: 1.6071 - val_loss: 2.2970 - lr: 2.0000e-04
# Epoch 17/200
# 584/584 [==============================] - ETA: 0s - loss: 1.5673
# Epoch 17: val_loss did not improve from 2.29702
# 584/584 [==============================] - 84s 143ms/step - loss: 1.5673 - val_loss: 2.3413 - lr: 2.0000e-04
# Epoch 18/200
# 584/584 [==============================] - ETA: 0s - loss: 1.5445
# Epoch 18: val_loss did not improve from 2.29702
# 584/584 [==============================] - 83s 141ms/step - loss: 1.5445 - val_loss: 2.3152 - lr: 2.0000e-04
# Epoch 19/200
# 584/584 [==============================] - ETA: 0s - loss: 1.5339
# Epoch 19: val_loss improved from 2.29702 to 2.26822, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 84s 144ms/step - loss: 1.5339 - val_loss: 2.2682 - lr: 2.0000e-04
# Epoch 20/200
# 584/584 [==============================] - ETA: 0s - loss: 1.5512
# Epoch 20: val_loss did not improve from 2.26822
# 584/584 [==============================] - 83s 143ms/step - loss: 1.5512 - val_loss: 2.2998 - lr: 2.0000e-04
# Epoch 21/200
# 584/584 [==============================] - ETA: 0s - loss: 1.5405
# Epoch 21: val_loss did not improve from 2.26822
# 584/584 [==============================] - 85s 145ms/step - loss: 1.5405 - val_loss: 2.3237 - lr: 2.0000e-04
# Epoch 22/200
# 584/584 [==============================] - ETA: 0s - loss: 1.5249
# Epoch 22: val_loss did not improve from 2.26822
# 584/584 [==============================] - 84s 144ms/step - loss: 1.5249 - val_loss: 2.3548 - lr: 2.0000e-04
# Epoch 23/200
# 584/584 [==============================] - ETA: 0s - loss: 1.4904
# Epoch 23: val_loss did not improve from 2.26822
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 584/584 [==============================] - 83s 142ms/step - loss: 1.4904 - val_loss: 2.2881 - lr: 2.0000e-04
# Epoch 24/200
# 584/584 [==============================] - ETA: 0s - loss: 1.4744
# Epoch 24: val_loss did not improve from 2.26822
# 584/584 [==============================] - 84s 144ms/step - loss: 1.4744 - val_loss: 2.2712 - lr: 4.0000e-05
# Epoch 25/200
# 584/584 [==============================] - ETA: 0s - loss: 1.4455
# Epoch 25: val_loss improved from 2.26822 to 2.26513, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 84s 144ms/step - loss: 1.4455 - val_loss: 2.2651 - lr: 4.0000e-05
# Epoch 26/200
# 584/584 [==============================] - ETA: 0s - loss: 1.4518
# Epoch 26: val_loss improved from 2.26513 to 2.22321, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 84s 144ms/step - loss: 1.4518 - val_loss: 2.2232 - lr: 4.0000e-05
# Epoch 27/200
# 584/584 [==============================] - ETA: 0s - loss: 1.4004
# Epoch 27: val_loss did not improve from 2.22321
# 584/584 [==============================] - 84s 144ms/step - loss: 1.4004 - val_loss: 2.2403 - lr: 4.0000e-05
# Epoch 28/200
# 584/584 [==============================] - ETA: 0s - loss: 1.4265
# Epoch 28: val_loss improved from 2.22321 to 2.21924, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 85s 146ms/step - loss: 1.4265 - val_loss: 2.2192 - lr: 4.0000e-05
# Epoch 29/200
# 584/584 [==============================] - ETA: 0s - loss: 1.4028
# Epoch 29: val_loss improved from 2.21924 to 2.21550, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 86s 148ms/step - loss: 1.4028 - val_loss: 2.2155 - lr: 4.0000e-05
# Epoch 30/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3992
# Epoch 30: val_loss did not improve from 2.21550
# 584/584 [==============================] - 83s 143ms/step - loss: 1.3992 - val_loss: 2.2292 - lr: 4.0000e-05
# Epoch 31/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3984
# Epoch 31: val_loss improved from 2.21550 to 2.20852, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 86s 147ms/step - loss: 1.3984 - val_loss: 2.2085 - lr: 4.0000e-05
# Epoch 32/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3708
# Epoch 32: val_loss improved from 2.20852 to 2.20659, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 85s 146ms/step - loss: 1.3708 - val_loss: 2.2066 - lr: 4.0000e-05
# Epoch 33/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3705
# Epoch 33: val_loss improved from 2.20659 to 2.17542, saving model to /content/drive/My Drive/htr/data2/output-bangla-flor-ts16/checkpoint_weights.hdf5
# 584/584 [==============================] - 84s 143ms/step - loss: 1.3705 - val_loss: 2.1754 - lr: 4.0000e-05
# Epoch 34/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3751
# Epoch 34: val_loss did not improve from 2.17542
# 584/584 [==============================] - 84s 143ms/step - loss: 1.3751 - val_loss: 2.2015 - lr: 4.0000e-05
# Epoch 35/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3840
# Epoch 35: val_loss did not improve from 2.17542
# 584/584 [==============================] - 85s 145ms/step - loss: 1.3840 - val_loss: 2.2079 - lr: 4.0000e-05
# Epoch 36/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3897
# Epoch 36: val_loss did not improve from 2.17542
# 584/584 [==============================] - 83s 142ms/step - loss: 1.3897 - val_loss: 2.1899 - lr: 4.0000e-05
# Epoch 37/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3864
# Epoch 37: val_loss did not improve from 2.17542
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 584/584 [==============================] - 83s 143ms/step - loss: 1.3864 - val_loss: 2.2025 - lr: 4.0000e-05
# Epoch 38/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3841
# Epoch 38: val_loss did not improve from 2.17542
# 584/584 [==============================] - 84s 145ms/step - loss: 1.3841 - val_loss: 2.2171 - lr: 8.0000e-06
# Epoch 39/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3670
# Epoch 39: val_loss did not improve from 2.17542
# 584/584 [==============================] - 84s 144ms/step - loss: 1.3670 - val_loss: 2.1954 - lr: 8.0000e-06
# Epoch 40/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3526
# Epoch 40: val_loss did not improve from 2.17542
# 584/584 [==============================] - 84s 143ms/step - loss: 1.3526 - val_loss: 2.2052 - lr: 8.0000e-06
# Epoch 41/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3516
# Epoch 41: val_loss did not improve from 2.17542
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 584/584 [==============================] - 84s 144ms/step - loss: 1.3516 - val_loss: 2.1881 - lr: 8.0000e-06
# Epoch 42/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3612
# Epoch 42: val_loss did not improve from 2.17542
# 584/584 [==============================] - 83s 142ms/step - loss: 1.3612 - val_loss: 2.1902 - lr: 1.6000e-06
# Epoch 43/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3324
# Epoch 43: val_loss did not improve from 2.17542
# 584/584 [==============================] - 85s 145ms/step - loss: 1.3324 - val_loss: 2.1999 - lr: 1.6000e-06
# Epoch 44/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3590
# Epoch 44: val_loss did not improve from 2.17542
# 584/584 [==============================] - 83s 142ms/step - loss: 1.3590 - val_loss: 2.1927 - lr: 1.6000e-06
# Epoch 45/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3609
# Epoch 45: val_loss did not improve from 2.17542
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 584/584 [==============================] - 83s 142ms/step - loss: 1.3609 - val_loss: 2.2042 - lr: 1.6000e-06
# Epoch 46/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3257
# Epoch 46: val_loss did not improve from 2.17542
# 584/584 [==============================] - 84s 144ms/step - loss: 1.3257 - val_loss: 2.1952 - lr: 3.2000e-07
# Epoch 47/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3488
# Epoch 47: val_loss did not improve from 2.17542
# 584/584 [==============================] - 83s 143ms/step - loss: 1.3488 - val_loss: 2.1801 - lr: 3.2000e-07
# Epoch 48/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3508
# Epoch 48: val_loss did not improve from 2.17542
# 584/584 [==============================] - 83s 141ms/step - loss: 1.3508 - val_loss: 2.1998 - lr: 3.2000e-07
# Epoch 49/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3680
# Epoch 49: val_loss did not improve from 2.17542
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 584/584 [==============================] - 83s 142ms/step - loss: 1.3680 - val_loss: 2.1984 - lr: 3.2000e-07
# Epoch 50/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3647
# Epoch 50: val_loss did not improve from 2.17542
# 584/584 [==============================] - 83s 142ms/step - loss: 1.3647 - val_loss: 2.2022 - lr: 6.4000e-08
# Epoch 51/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3602
# Epoch 51: val_loss did not improve from 2.17542
# 584/584 [==============================] - 83s 143ms/step - loss: 1.3602 - val_loss: 2.2361 - lr: 6.4000e-08
# Epoch 52/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3610
# Epoch 52: val_loss did not improve from 2.17542
# 584/584 [==============================] - 85s 145ms/step - loss: 1.3610 - val_loss: 2.1864 - lr: 6.4000e-08
# Epoch 53/200
# 584/584 [==============================] - ETA: 0s - loss: 1.3623
# Epoch 53: val_loss did not improve from 2.17542
# Restoring model weights from the end of the best epoch: 33.
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 584/584 [==============================] - 84s 143ms/step - loss: 1.3623 - val_loss: 2.2086 - lr: 6.4000e-08
# Epoch 53: early stopping

# %% [markdown]
# *Training history from CSVLogger callback*

# %%
from pandas import read_csv
from scipy.signal import savgol_filter
from ipywidgets import interact

path = os.path.join(output_path, 'epochs.log')
if os.path.isfile(path):
    history = read_csv(path)
    loss = history['loss']
    val_loss = history['val_loss']

    print('Min val_loss:', np.min(val_loss))
    print('Min val_loss epoch:', np.argmin(val_loss))

    # Plot training vs validation loss
    plt.figure(figsize=(10, 6))
    plt.plot(loss, 'r.')
    plt.plot(val_loss, 'b.')
    # Smoothing
    plt.plot(savgol_filter(loss, 11, 3), 'r-', label='Training')
    plt.plot(savgol_filter(val_loss, 11, 3), 'b-', label='Validation')
    plt.title('Training and validation loss')
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend()
    plt.grid('on')
    plt.show()

else:
    print("File doesn't exist")
# Out:
# Min val_loss: 2.175421476364136
# Min val_loss epoch: 102

# %% [markdown]
# *Logs from Tensorboard*
#
# If tensorboard gets timed out or doesn't show up, it might be running on http://localhost:6006/.

# %%
# !find /content/drive/My\Drive/htr/data/output-bangla-flor | grep tfevents
# Out:
# /content/drive/MyDrive/htr/data/output-bangla-flor/train/events.out.tfevents.1626376179.182214c1d747.430.2555.v2
# /content/drive/MyDrive/htr/data/output-bangla-flor/train/events.out.tfevents.1626441715.f29d4f748eb6.61.1645760.v2
# /content/drive/MyDrive/htr/data/output-bangla-flor/validation/events.out.tfevents.1626376404.182214c1d747.430.16321.v2
# /content/drive/MyDrive/htr/data/output-bangla-flor/validation/events.out.tfevents.1626441909.f29d4f748eb6.61.1659526.v2

# %%
# %tensorboard --logdir /content/drive/My\Drive/htr/data/output-bangla-flor

# %% [markdown]
# ### Prediction | Evaluation

# %% [markdown]
# ***Validation set***

# %%
print('           VALIDATION SET           ')
Y_pred = model.predict(x=generator.next_val_batch(), steps=generator._steps['val'], verbose=1)
print('Y_pred shape:', Y_pred.shape)

# Predictions, Probabilities after decoding
predictions, probabilities = ctc_decode(Y_pred=Y_pred, batch_size=batch_size, verbose=1)
print('\nCTC decoded predictions len:', len(predictions))

pred_texts = [generator.tokenizer.decode(y) for y in predictions]
gt_texts = [y.decode() for y in generator.dataset['val']['gt_texts']]

cer, wer, ser = ocr_metrics(pred_texts, gt_texts, lower=False) * 100
print(f'Character Error Rate (%) : {cer:.4f}')
print(f'Word Error Rate (%) : {wer:.4f}')
print(f'Sequence Error Rate (%) : {ser:.4f}')
# Out:
#            VALIDATION SET
# 26/26 [==============================] - 1s 30ms/step
# Y_pred shape: (829, 16, 93)
# 26/26 [==============================] - 16s 644ms/step
#
# CTC decoded predictions len: 829
# Character Error Rate (%) : 14.2715
# Word Error Rate (%) : 36.7913
# Sequence Error Rate (%) : 36.7913

# %% [markdown]
# ***Test set***

# %%
print('           TEST SET           ')
Y_pred = model.predict(x=generator.next_test_batch(), steps=generator._steps['test'], verbose=1)
print('Y_pred shape:', Y_pred.shape)

# Predictions, Probabilities after decoding
predictions, probabilities = ctc_decode(Y_pred=Y_pred, batch_size=batch_size, verbose=1)
print('\nCTC decoded predictions len:', len(predictions))

pred_texts = [generator.tokenizer.decode(y) for y in predictions]
gt_texts = [y.decode() for y in generator.dataset['test']['gt_texts']]

cer, wer, ser = ocr_metrics(pred_texts, gt_texts, lower=False) * 100
print(f'Character Error Rate (%) : {cer:.4f}')
print(f'Word Error Rate (%) : {wer:.4f}')
print(f'Sequence Error Rate (%) : {ser:.4f}')
# Out:
#            TEST SET
# 39/39 [==============================] - 1s 29ms/step
# Y_pred shape: (1244, 16, 93)
# 39/39 [==============================] - 15s 374ms/step
#
# CTC decoded predictions len: 1244
# Character Error Rate (%) : 13.9978
# Word Error Rate (%) : 35.6511
# Sequence Error Rate (%) : 35.6913
