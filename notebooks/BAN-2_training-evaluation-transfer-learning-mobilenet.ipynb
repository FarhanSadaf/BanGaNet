# %%
# !nvidia-smi
# Out:
# Sun May  1 13:56:32 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P8    35W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip uninstall opencv-python-headless==4.5.5.62
# !pip install opencv-python-headless==4.5.2.52

# !pip install -U albumentations

# %%
# %tensorflow_version 2.x
import tensorflow as tf

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/My Drive/'

import os

BASE_DIR = os.getcwd()

# BASE_DIR is working directory for this notebook
print(BASE_DIR)

# %% [markdown]
# ## Import libraries

# %%
import string
import json
import numpy as np
import matplotlib.pyplot as plt

from htr.preprocessing import get_augmentation_pipeline
from htr.generator import DataGenerator
from htr.network.models import *

from htr.evaluation import ocr_metrics

from tensorflow.keras.models import Model

# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %% [markdown]
# ***Filepaths***

# %%
dataset_path = os.path.join(BASE_DIR, 'htr', 'data', 'BanglaWriting2.hdf5')

# %% [markdown]
# ***Parameters***

# %%
input_size = (256, 64, 3)
max_text_len = 32
# max_text_len = 16
batch_size = 32
epochs = 200

# charset = ''.join(json.load(open(os.path.join(BASE_DIR, 'htr', 'data', 'BanglaWriting-characters.json'))))

charlist = json.load(open(os.path.join(BASE_DIR, 'htr', 'data', 'BanglaWriting-characters.json')))
charlist.remove(' ')
charset = ''.join(charlist)
print(len(charset))
# Out:
# 90

# %% [markdown]
# ***DataGenerator class***

# %%
generator = DataGenerator(dataset_path=dataset_path, 
                          input_size=input_size, 
                          batch_size=batch_size, 
                          max_text_len=max_text_len, 
                          charset=charset,
                          aug=get_augmentation_pipeline(),
                          encoding='utf-8')

print('Images:', generator._size)
# Out:
# /usr/local/lib/python3.7/dist-packages/albumentations/augmentations/transforms.py:691: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,
# Images: {'train': 18663, 'val': 829, 'test': 1244}

# %% [markdown]
# ## *Fine tuning*
# ### Models

# %%
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.layers import Bidirectional, LSTM, GRU, Dense


def mobilenet(input_size, d_model, RNN):
    input_data = Input(name="input", shape=input_size)
    
    base_model = MobileNet(include_top=False, weights='imagenet', input_tensor=input_data)
    base_model.trainable = False
    x = base_model.get_layer('conv_pw_5_relu').output
    # x = base_model.get_layer('conv_pw_6_relu').output

    shape = x.get_shape()
    brnn = Reshape((shape[1], shape[2] * shape[3]))(x)

    brnn = Bidirectional(RNN(units=128, return_sequences=True, dropout=0.5))(brnn)
    brnn = Bidirectional(RNN(units=64, return_sequences=True, dropout=0.5))(brnn)
    output_data = Dense(units=d_model, activation="softmax")(brnn)

    return (input_data, output_data)

# %%
output_path = os.path.join(BASE_DIR, 'htr', 'data2', 'output-bangla-mobilenet-gru')
target_path = os.path.join(output_path, 'checkpoint_weights.hdf5')

# %%
inputs, outputs = mobilenet(input_size=input_size, d_model=generator.tokenizer.vocab_size + 1, RNN=GRU)

model = Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 256, 64, 3)]      0
#
#  conv1 (Conv2D)              (None, 128, 32, 32)       864
#
#  conv1_bn (BatchNormalizatio  (None, 128, 32, 32)      128
#  n)
#
#  conv1_relu (ReLU)           (None, 128, 32, 32)       0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 128, 32, 32)      288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 128, 32, 32)      128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 128, 32, 32)       0
#
#  conv_pw_1 (Conv2D)          (None, 128, 32, 64)       2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 128, 32, 64)      256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 128, 32, 64)       0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 129, 33, 64)       0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 64, 16, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 64, 16, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 64, 16, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 64, 16, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 64, 16, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 64, 16, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 64, 16, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 64, 16, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 64, 16, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 64, 16, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 64, 16, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 64, 16, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 65, 17, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 32, 8, 128)       1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 32, 8, 128)       512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 32, 8, 128)        0
#
#  conv_pw_4 (Conv2D)          (None, 32, 8, 256)        32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 32, 8, 256)       1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 32, 8, 256)        0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 32, 8, 256)       2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 32, 8, 256)       1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 32, 8, 256)        0
#
#  conv_pw_5 (Conv2D)          (None, 32, 8, 256)        65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 32, 8, 256)       1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 32, 8, 256)        0
#
#  reshape_2 (Reshape)         (None, 32, 2048)          0
#
#  bidirectional_4 (Bidirectio  (None, 32, 256)          1672704
#  nal)
#
#  bidirectional_5 (Bidirectio  (None, 32, 128)          123648
#  nal)
#
#  dense_2 (Dense)             (None, 32, 93)            11997
#
# =================================================================
# Total params: 1,945,501
# Trainable params: 1,808,349
# Non-trainable params: 137,152
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=ctc_loss)

# Load weights from target_path
if os.path.isfile(target_path):
    model.load_weights(target_path)
    print('===== Pre-trained weights loaded =====')
# Out:
# ===== Pre-trained weights loaded =====

# %% [markdown]
# ### Training

# %%
callbacks = get_callbacks(logdir=output_path, 
                          checkpoint_filepath=target_path, 
                          verbose=1, 
                          stop_patience=20, 
                          reduce_patience=4)

# %%
model.fit(x=generator.next_train_batch(), 
          steps_per_epoch=generator._steps['train'], 
          validation_data=generator.next_val_batch(), 
          validation_steps=generator._steps['val'], 
          epochs=epochs, 
          callbacks=callbacks, 
          verbose=1)

# %% [markdown]
# *Training history from CSVLogger callback*

# %%
from pandas import read_csv
from scipy.signal import savgol_filter
from ipywidgets import interact

path = os.path.join(output_path, 'epochs.log')
if os.path.isfile(path):
    history = read_csv(path)
    loss = history['loss']
    val_loss = history['val_loss']

    print('Min val_loss:', np.min(val_loss))
    print('Min val_loss epoch:', np.argmin(val_loss))

    # Plot training vs validation loss
    plt.figure(figsize=(10, 6))
    plt.plot(loss, 'r.')
    plt.plot(val_loss, 'b.')
    # Smoothing
    plt.plot(savgol_filter(loss, 11, 3), 'r-', label='Training')
    plt.plot(savgol_filter(val_loss, 11, 3), 'b-', label='Validation')
    plt.title('Training and validation loss')
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend()
    plt.grid('on')
    plt.show()
    
else:
    print("File doesn't exist")
# Out:
# Min val_loss: 7.15575647354126
# Min val_loss epoch: 114

# %% [markdown]
# *Logs from Tensorboard*
#
# If tensorboard gets timed out or doesn't show up, it might be running on http://localhost:6006/.

# %%
# !find /content/drive/My\Drive/htr/data/output-bangla-flor | grep tfevents
# Out:
# /content/drive/MyDrive/htr/data/output-bangla-flor/train/events.out.tfevents.1626376179.182214c1d747.430.2555.v2
# /content/drive/MyDrive/htr/data/output-bangla-flor/train/events.out.tfevents.1626441715.f29d4f748eb6.61.1645760.v2
# /content/drive/MyDrive/htr/data/output-bangla-flor/validation/events.out.tfevents.1626376404.182214c1d747.430.16321.v2
# /content/drive/MyDrive/htr/data/output-bangla-flor/validation/events.out.tfevents.1626441909.f29d4f748eb6.61.1659526.v2

# %%
# %tensorboard --logdir /content/drive/My\Drive/htr/data/output-bangla-flor

# %% [markdown]
# ### Prediction | Evaluation

# %% [markdown]
# ***Validation set***

# %%
print('           VALIDATION SET           ')
Y_pred = model.predict(x=generator.next_val_batch(), steps=generator._steps['val'], verbose=1)
print('Y_pred shape:', Y_pred.shape)

# Predictions, Probabilities after decoding
predictions, probabilities = ctc_decode(Y_pred=Y_pred, batch_size=batch_size, verbose=1)
print('\nCTC decoded predictions len:', len(predictions))

pred_texts = [generator.tokenizer.decode(y) for y in predictions]
gt_texts = [y.decode() for y in generator.dataset['val']['gt_texts']]

cer, wer, ser = ocr_metrics(pred_texts, gt_texts, lower=False) * 100
print(f'Character Error Rate (%) : {cer:.4f}')
print(f'Word Error Rate (%) : {wer:.4f}')
print(f'Sequence Error Rate (%) : {ser:.4f}')
# Out:
#            VALIDATION SET
# 26/26 [==============================] - 1s 36ms/step
# Y_pred shape: (829, 32, 93)
# 26/26 [==============================] - 21s 823ms/step
#
# CTC decoded predictions len: 829
# Character Error Rate (%) : 39.8981
# Word Error Rate (%) : 75.3920
# Sequence Error Rate (%) : 75.3920

# %% [markdown]
# ***Test set***

# %%
print('           TEST SET           ')
Y_pred = model.predict(x=generator.next_test_batch(), steps=generator._steps['test'], verbose=1)
print('Y_pred shape:', Y_pred.shape)

# Predictions, Probabilities after decoding
predictions, probabilities = ctc_decode(Y_pred=Y_pred, batch_size=batch_size, verbose=1)
print('\nCTC decoded predictions len:', len(predictions))

pred_texts = [generator.tokenizer.decode(y) for y in predictions]
gt_texts = [y.decode() for y in generator.dataset['test']['gt_texts']]

cer, wer, ser = ocr_metrics(pred_texts, gt_texts, lower=False) * 100
print(f'Character Error Rate (%) : {cer:.4f}')
print(f'Word Error Rate (%) : {wer:.4f}')
print(f'Sequence Error Rate (%) : {ser:.4f}')
# Out:
#            TEST SET
# 39/39 [==============================] - 1s 36ms/step
# Y_pred shape: (1244, 32, 93)
# 39/39 [==============================] - 32s 824ms/step
#
# CTC decoded predictions len: 1244
# Character Error Rate (%) : 42.0793
# Word Error Rate (%) : 76.6881
# Sequence Error Rate (%) : 76.6881
